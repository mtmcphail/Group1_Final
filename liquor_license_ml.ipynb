# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
import pandas as pd
from pathlib import Path
from collections import Counter

# %%
from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import confusion_matrix
from imblearn.metrics import classification_report_imbalanced

# %%
# Load the data
file_path = Path('population_pct_within_qrt_mile_alcohol.csv')

# %%
df = pd.read_csv(file_path)
df
# Out:
#        Indicator_ID                                     ind_definition  \
# 0               774  Percent of Population within 1/4 Mile of Alcoh...
# 1               774  Percent of Population within 1/4 Mile of Alcoh...
# 2               774  Percent of Population within 1/4 Mile of Alcoh...
# 3               774  Percent of Population within 1/4 Mile of Alcoh...
# 4               774  Percent of Population within 1/4 Mile of Alcoh...
# ...             ...                                                ...
# 90445           774  Percent of Population within 1/4 Mile of Alcoh...
# 90446           774  Percent of Population within 1/4 Mile of Alcoh...
# 90447           774  Percent of Population within 1/4 Mile of Alcoh...
# 90448           774  Percent of Population within 1/4 Mile of Alcoh...
# 90449           774  Percent of Population within 1/4 Mile of Alcoh...
#
#        reportyear  race_eth_code race_eth_name geotype  geotypevalue  \
# 0            2014              8         Other      CT    6001442100
# 1            2014              1          AIAN      CD     600190020
# 2            2014              3     AfricanAm      CD     600190020
# 3            2014              2         Asian      CD     600190020
# 4            2014              4        Latino      CD     600190020
# ...           ...            ...           ...     ...           ...
# 90445        2014              7      Multiple      RE            14
# 90446        2014              5         NHOPI      RE            14
# 90447        2014              8         Other      RE            14
# 90448        2014              9         Total      RE            14
# 90449        2014              6         White      RE            14
#
#                    geoname county_name  county_fips_id          region_name  \
# 0                     4421     Alameda            6001                  NaN
# 1                  Alameda     Alameda            6001             Bay Area
# 2                  Alameda     Alameda            6001             Bay Area
# 3                  Alameda     Alameda            6001             Bay Area
# 4                  Alameda     Alameda            6001             Bay Area
# ...                    ...         ...             ...                  ...
# 90445  Southern California         NaN               0  Southern California
# 90446  Southern California         NaN               0  Southern California
# 90447  Southern California         NaN               0  Southern California
# 90448  Southern California         NaN               0  Southern California
# 90449  Southern California         NaN               0  Southern California
#
#        region_code    license_type  num_people_qrt  tot_people  pct_of_total
# 0              NaN  Total_licenses             0.0         0.0           NaN
# 1              1.0  Total_licenses           159.0       247.0         64.37
# 2              1.0  Total_licenses          2674.0      4516.0         59.21
# 3              1.0  Total_licenses         14243.0     22822.0         62.41
# 4              1.0  Total_licenses          5689.0      8092.0         70.30
# ...            ...             ...             ...         ...           ...
# 90445         14.0  Total_licenses        181987.0    378200.0         48.12
# 90446         14.0  Total_licenses         25455.0     43955.0         57.91
# 90447         14.0  Total_licenses         22985.0     40257.0         57.10
# 90448         14.0  Total_licenses       9744365.0  18051534.0         53.98
# 90449         14.0  Total_licenses       2552634.0   6028281.0         42.34
#
# [90450 rows x 16 columns]

# %%
df.dtypes
# Out:
# Indicator_ID        int64
# ind_definition     object
# reportyear          int64
# race_eth_code       int64
# race_eth_name      object
# geotype            object
# geotypevalue        int64
# geoname            object
# county_name        object
# county_fips_id      int64
# region_name        object
# region_code       float64
# license_type       object
# num_people_qrt    float64
# tot_people        float64
# pct_of_total      float64
# dtype: object

# %%
# Define features data
df_dropna = df.copy().dropna()
df_new = df_dropna.drop(columns=["Indicator_ID", "ind_definition", "geotype","reportyear", "geotypevalue", "geoname", "county_fips_id"])

# %%
df_new
# Out:
#        race_eth_code race_eth_name county_name      region_name  region_code  \
# 1                  1          AIAN     Alameda         Bay Area          1.0
# 2                  3     AfricanAm     Alameda         Bay Area          1.0
# 3                  2         Asian     Alameda         Bay Area          1.0
# 4                  4        Latino     Alameda         Bay Area          1.0
# 5                  7      Multiple     Alameda         Bay Area          1.0
# ...              ...           ...         ...              ...          ...
# 90310              7      Multiple        Yuba  Sacramento Area          8.0
# 90311              5         NHOPI        Yuba  Sacramento Area          8.0
# 90312              8         Other        Yuba  Sacramento Area          8.0
# 90313              9         Total        Yuba  Sacramento Area          8.0
# 90314              6         White        Yuba  Sacramento Area          8.0
#
#          license_type  num_people_qrt  tot_people  pct_of_total
# 1      Total_licenses           159.0       247.0         64.37
# 2      Total_licenses          2674.0      4516.0         59.21
# 3      Total_licenses         14243.0     22822.0         62.41
# 4      Total_licenses          5689.0      8092.0         70.30
# 5      Total_licenses          2490.0      4047.0         61.53
# ...               ...             ...         ...           ...
# 90310  Total_licenses            71.0       153.0         46.41
# 90311  Total_licenses             0.0         4.0          0.00
# 90312  Total_licenses             0.0         7.0          0.00
# 90313  Total_licenses          1583.0      3456.0         45.80
# 90314  Total_licenses          1118.0      2399.0         46.60
#
# [14621 rows x 9 columns]

# %%
#Create a list of condition to turn pct_of_total to categorical variables
pop_density = [
    (df_new['pct_of_total'] <= 50.00),
    (df_new['pct_of_total'] > 50.00)
    ]
values = ['low_density', 'high_density']

df_new['density'] = np.select(pop_density, values)

# %%
df_new
# Out:
#        race_eth_code race_eth_name county_name      region_name  region_code  \
# 1                  1          AIAN     Alameda         Bay Area          1.0
# 2                  3     AfricanAm     Alameda         Bay Area          1.0
# 3                  2         Asian     Alameda         Bay Area          1.0
# 4                  4        Latino     Alameda         Bay Area          1.0
# 5                  7      Multiple     Alameda         Bay Area          1.0
# ...              ...           ...         ...              ...          ...
# 90310              7      Multiple        Yuba  Sacramento Area          8.0
# 90311              5         NHOPI        Yuba  Sacramento Area          8.0
# 90312              8         Other        Yuba  Sacramento Area          8.0
# 90313              9         Total        Yuba  Sacramento Area          8.0
# 90314              6         White        Yuba  Sacramento Area          8.0
#
#          license_type  num_people_qrt  tot_people  pct_of_total       density
# 1      Total_licenses           159.0       247.0         64.37  high_density
# 2      Total_licenses          2674.0      4516.0         59.21  high_density
# 3      Total_licenses         14243.0     22822.0         62.41  high_density
# 4      Total_licenses          5689.0      8092.0         70.30  high_density
# 5      Total_licenses          2490.0      4047.0         61.53  high_density
# ...               ...             ...         ...           ...           ...
# 90310  Total_licenses            71.0       153.0         46.41   low_density
# 90311  Total_licenses             0.0         4.0          0.00   low_density
# 90312  Total_licenses             0.0         7.0          0.00   low_density
# 90313  Total_licenses          1583.0      3456.0         45.80   low_density
# 90314  Total_licenses          1118.0      2399.0         46.60   low_density
#
# [14621 rows x 10 columns]

# %%
df_density = df_new.drop(columns=["pct_of_total"])

# %%
df_density
# Out:
#        race_eth_code race_eth_name county_name      region_name  region_code  \
# 1                  1          AIAN     Alameda         Bay Area          1.0
# 2                  3     AfricanAm     Alameda         Bay Area          1.0
# 3                  2         Asian     Alameda         Bay Area          1.0
# 4                  4        Latino     Alameda         Bay Area          1.0
# 5                  7      Multiple     Alameda         Bay Area          1.0
# ...              ...           ...         ...              ...          ...
# 90310              7      Multiple        Yuba  Sacramento Area          8.0
# 90311              5         NHOPI        Yuba  Sacramento Area          8.0
# 90312              8         Other        Yuba  Sacramento Area          8.0
# 90313              9         Total        Yuba  Sacramento Area          8.0
# 90314              6         White        Yuba  Sacramento Area          8.0
#
#          license_type  num_people_qrt  tot_people       density
# 1      Total_licenses           159.0       247.0  high_density
# 2      Total_licenses          2674.0      4516.0  high_density
# 3      Total_licenses         14243.0     22822.0  high_density
# 4      Total_licenses          5689.0      8092.0  high_density
# 5      Total_licenses          2490.0      4047.0  high_density
# ...               ...             ...         ...           ...
# 90310  Total_licenses            71.0       153.0   low_density
# 90311  Total_licenses             0.0         4.0   low_density
# 90312  Total_licenses             0.0         7.0   low_density
# 90313  Total_licenses          1583.0      3456.0   low_density
# 90314  Total_licenses          1118.0      2399.0   low_density
#
# [14621 rows x 9 columns]

# %%
#Split the Data into Training and Testing
# Create our features
y = pd.DataFrame(df_density['density'])
X = pd.get_dummies(df_density.drop(columns="density"))

# %%
X.describe()
# Out:
#        race_eth_code   region_code  num_people_qrt    tot_people  \
# count   14621.000000  14621.000000    1.462100e+04  1.462100e+04
# mean        4.991519      8.164968    7.445648e+03  1.497877e+04
# std         2.595731      4.635320    8.159632e+04  1.305161e+05
# min         1.000000      1.000000    0.000000e+00  1.000000e+00
# 25%         3.000000      4.000000    6.000000e+00  3.000000e+01
# 50%         5.000000      9.000000    6.800000e+01  2.500000e+02
# 75%         7.000000     14.000000    9.070000e+02  3.006000e+03
# max         9.000000     14.000000    6.519275e+06  9.818605e+06
#
#        race_eth_name_AIAN  race_eth_name_AfricanAm  race_eth_name_Asian  \
# count        14621.000000             14621.000000         14621.000000
# mean             0.113057                 0.109158             0.112851
# std              0.316673                 0.311848             0.316422
# min              0.000000                 0.000000             0.000000
# 25%              0.000000                 0.000000             0.000000
# 50%              0.000000                 0.000000             0.000000
# 75%              0.000000                 0.000000             0.000000
# max              1.000000                 1.000000             1.000000
#
#        race_eth_name_Latino  race_eth_name_Multiple  race_eth_name_NHOPI  ...  \
# count          14621.000000            14621.000000         14621.000000  ...
# mean               0.117707                0.116340             0.096300  ...
# std                0.322272                0.320643             0.295012  ...
# min                0.000000                0.000000             0.000000  ...
# 25%                0.000000                0.000000             0.000000  ...
# 50%                0.000000                0.000000             0.000000  ...
# 75%                0.000000                0.000000             0.000000  ...
# max                1.000000                1.000000             1.000000  ...
#
#        region_name_Northeast Sierra  region_name_Northern Sacramento Valley  \
# count                  14621.000000                            14621.000000
# mean                       0.051228                                0.019629
# std                        0.220469                                0.138727
# min                        0.000000                                0.000000
# 25%                        0.000000                                0.000000
# 50%                        0.000000                                0.000000
# 75%                        0.000000                                0.000000
# max                        1.000000                                1.000000
#
#        region_name_Sacramento Area  region_name_San Diego  \
# count                 14621.000000           14621.000000
# mean                      0.081116               0.038985
# std                       0.273023               0.193566
# min                       0.000000               0.000000
# 25%                       0.000000               0.000000
# 50%                       0.000000               0.000000
# 75%                       0.000000               0.000000
# max                       1.000000               1.000000
#
#        region_name_San Joaquin Valley  region_name_San Luis Obispo  \
# count                    14621.000000                 14621.000000
# mean                         0.181246                     0.016278
# std                          0.385235                     0.126547
# min                          0.000000                     0.000000
# 25%                          0.000000                     0.000000
# 50%                          0.000000                     0.000000
# 75%                          0.000000                     0.000000
# max                          1.000000                     1.000000
#
#        region_name_Santa Barbara  region_name_Shasta  \
# count               14621.000000        14621.000000
# mean                    0.017235            0.011832
# std                     0.130152            0.108135
# min                     0.000000            0.000000
# 25%                     0.000000            0.000000
# 50%                     0.000000            0.000000
# 75%                     0.000000            0.000000
# max                     1.000000            1.000000
#
#        region_name_Southern California  license_type_Total_licenses
# count                     14621.000000                      14621.0
# mean                          0.252240                          1.0
# std                           0.434313                          0.0
# min                           0.000000                          1.0
# 25%                           0.000000                          1.0
# 50%                           0.000000                          1.0
# 75%                           1.000000                          1.0
# max                           1.000000                          1.0
#
# [8 rows x 86 columns]

# %%
# Check the balance of our target values
y['density'].value_counts()
# Out:
# low_density     10480
# high_density     4141
# Name: density, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,
   y,  random_state=1, stratify=y)
y_train.shape
# Out:
# (10965, 1)

# %%
#Balanced Random Forest Classifier
from imblearn.ensemble import BalancedRandomForestClassifier
rf_model = BalancedRandomForestClassifier(n_estimators=100, random_state=1) 
rf_model = rf_model.fit(X_train, y_train)

# %%
# Calculated the balanced accuracy score
y_pred = rf_model.predict(X_test)
balanced_accuracy_score(y_test, y_pred)
# Out:
# 0.8041307020405606

# %%
# Display the confusion matrix
confusion_matrix(y_test, y_pred)
# Out:
# array([[ 842,  193],
#        [ 538, 2083]])

# %%
# Print the imbalanced classification report
print(classification_report_imbalanced(y_test, y_pred))
# Out:
#                     pre       rec       spe        f1       geo       iba       sup
#
# high_density       0.61      0.81      0.79      0.70      0.80      0.65      1035
#  low_density       0.92      0.79      0.81      0.85      0.80      0.65      2621
#
#  avg / total       0.83      0.80      0.81      0.81      0.80      0.65      3656

# %%
# List the features sorted in descending order by feature importance
sorted(zip(rf_model.feature_importances_, X.columns), reverse=True)
# Out:
# [(0.3691923467272658, 'num_people_qrt'),
#  (0.3189255421171539, 'tot_people'),
#  (0.03376831020198658, 'county_name_Los Angeles'),
#  (0.024070757606416537, 'race_eth_code'),
#  (0.02366851728626245, 'county_name_Riverside'),
#  (0.01856709333690429, 'region_code'),
#  (0.007893835656970834, 'county_name_San Bernardino'),
#  (0.007080547864220715, 'region_name_Southern California'),
#  (0.0069853235879066, 'county_name_Orange'),
#  (0.0067137173808142015, 'race_eth_name_Latino'),
#  (0.006537162680914342, 'race_eth_name_White'),
#  (0.006345317728345141, 'race_eth_name_Asian'),
#  (0.006285678941493319, 'race_eth_name_NHOPI'),
#  (0.006112944787530083, 'county_name_Solano'),
#  (0.00610848398482215, 'race_eth_name_AfricanAm'),
#  (0.005718675768919875, 'region_name_Bay Area'),
#  (0.005673570709838403, 'race_eth_name_Multiple'),
#  (0.005402336738115066, 'race_eth_name_AIAN'),
#  (0.004872520944902454, 'race_eth_name_Other'),
#  (0.00476688567133717, 'race_eth_name_Total'),
#  (0.004608627243264221, 'county_name_Madera'),
#  (0.0046004398975580015, 'county_name_Contra Costa'),
#  (0.003980762020004235, 'county_name_Tulare'),
#  (0.0036367154198412755, 'county_name_Sonoma'),
#  (0.0035478878540358776, 'county_name_Humboldt'),
#  (0.0034576568346046214, 'region_name_Sacramento Area'),
#  (0.0032914214632065644, 'county_name_Alameda'),
#  (0.002866815988717626, 'county_name_Ventura'),
#  (0.0028070564925486174, 'county_name_San Mateo'),
#  (0.002775943479643403, 'county_name_Kern'),
#  (0.0027278041076459207, 'county_name_San Joaquin'),
#  (0.002716355650127769, 'region_name_Shasta'),
#  (0.002700595948421183, 'region_name_San Joaquin Valley'),
#  (0.0026159256804321133, 'county_name_Fresno'),
#  (0.002585098995764058, 'county_name_Stanislaus'),
#  (0.0025113122569722503, 'county_name_Lake'),
#  (0.0024497101841703243, 'county_name_Merced'),
#  (0.0024274277166477314, 'region_name_Central/Southeast Sierra'),
#  (0.0024204573515200787, 'county_name_Placer'),
#  (0.002394910984466929, 'county_name_Shasta'),
#  (0.00236748187068096, 'county_name_Santa Cruz'),
#  (0.002298502132664179, 'county_name_Napa'),
#  (0.0022059441011084203, 'region_name_Monterey Bay'),
#  (0.0020423059834325016, 'county_name_Imperial'),
#  (0.002031436201765091, 'county_name_Monterey'),
#  (0.001976450394692899, 'county_name_Santa Clara'),
#  (0.001963801333079421, 'county_name_Marin'),
#  (0.0018944158037591827, 'region_name_North Coast'),
#  (0.0018607421071358517, 'county_name_Sacramento'),
#  (0.001848548670108095, 'region_name_Northeast Sierra'),
#  (0.0017726804918196692, 'county_name_Mendocino'),
#  (0.0017104417320606248, 'county_name_El Dorado'),
#  (0.0016408313396461239, 'county_name_San Diego'),
#  (0.0016264777326908068, 'county_name_Siskiyou'),
#  (0.001588085611306658, 'region_name_Northern Sacramento Valley'),
#  (0.0015405028815817642, 'county_name_Yolo'),
#  (0.0015183742388998301, 'county_name_Kings'),
#  (0.0014438279486944027, 'county_name_Tuolumne'),
#  (0.0014429667826569438, 'county_name_Amador'),
#  (0.0014247740990919265, 'county_name_Del Norte'),
#  (0.0013453840985486736, 'county_name_Lassen'),
#  (0.0013370829080087965, 'county_name_San Francisco'),
#  (0.0013183507330041574, 'region_name_San Diego'),
#  (0.0013170323649464102, 'county_name_Glenn'),
#  (0.001299645142259566, 'county_name_Mariposa'),
#  (0.0012898970247017063, 'county_name_Calaveras'),
#  (0.0012836221451739671, 'county_name_San Luis Obispo'),
#  (0.0012802229790055842, 'county_name_Nevada'),
#  (0.001274165332426004, 'county_name_Mono'),
#  (0.0012505407824375575, 'county_name_Colusa'),
#  (0.0012473601582447388, 'county_name_Sutter'),
#  (0.0012365362262596307, 'county_name_Plumas'),
#  (0.0011500553691370901, 'region_name_San Luis Obispo'),
#  (0.0011488345848774586, 'region_name_Butte'),
#  (0.0011169796799781718, 'county_name_Tehama'),
#  (0.0011094143396469676, 'county_name_Santa Barbara'),
#  (0.0011006874865458864, 'region_name_Santa Barbara'),
#  (0.0010803222385872891, 'county_name_Yuba'),
#  (0.0010778029341729195, 'county_name_Butte'),
#  (0.0010157319213451943, 'county_name_Inyo'),
#  (0.000979113502540426, 'county_name_Trinity'),
#  (0.0009327792546743526, 'county_name_San Benito'),
#  (0.0008550512840759668, 'county_name_Sierra'),
#  (0.000700309122826814, 'county_name_Modoc'),
#  (0.00024199163798652957, 'county_name_Alpine'),
#  (0.0, 'license_type_Total_licenses')]

# %%
# Train the EasyEnsembleClassifier
from imblearn.ensemble import EasyEnsembleClassifier
ee_model = EasyEnsembleClassifier(n_estimators=100, random_state=1) 
ee_model = ee_model.fit(X_train, y_train)

# %%
# Calculated the balanced accuracy score
y_pred_ee = ee_model.predict(X_test)
balanced_accuracy_score(y_test, y_pred_ee)
# Out:
# 0.872938381375254

# %%
# Display the confusion matrix
confusion_matrix(y_test, y_pred_ee)
# Out:
# array([[ 956,   79],
#        [ 466, 2155]])

# %%
# Print the imbalanced classification report
print(classification_report_imbalanced(y_test, y_pred_ee))
# Out:
#                     pre       rec       spe        f1       geo       iba       sup
#
# high_density       0.67      0.92      0.82      0.78      0.87      0.77      1035
#  low_density       0.96      0.82      0.92      0.89      0.87      0.75      2621
#
#  avg / total       0.88      0.85      0.89      0.86      0.87      0.76      3656
